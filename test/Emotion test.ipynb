# %% [markdown]
# ## Setting up

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
DATA_DIR = os.path.abspath("data/legend.csv")
IMAGE_DIR = os.path.abspath("images/")

# %%
DATA_DIR, IMAGE_DIR
# Out:
# ('/home/phongsathron/Project/NAPROCK2018/emotion/data/legend.csv',
#  '/home/phongsathron/Project/NAPROCK2018/emotion/images')

# %% [markdown]
# ## Load dataset

# %% [markdown]
# Get images filename

# %%
pic_list = os.listdir(IMAGE_DIR)
pic_list
# Out:
# ['Zafarullah_Khan_Jamali_0002.jpg',
#  'John_Rosa_0002.jpg',
#  'Roy_Jones_Jr_0001.jpg',
#  'Michelle_Rodriguez_0001.jpg',
#  'Joan_Laporta_0005.jpg',
#  'George_W_Bush_0201.jpg',
#  'George_W_Bush_0217.jpg',
#  'Paul_Bremer_0018.jpg',
#  'Quincy_Jones_0001.jpg',
#  'Naomi_Watts_0019.jpg',
#  'Dwarakish_106.jpg',
#  'Theresa_Gattung_0001.jpg',
#  'Dean_Barkley_0003.jpg',
#  'Junichiro_Koizumi_0032.jpg',
#  'Mark_Hurlbert_0004.jpg',
#  'Anne_Krueger_0002.jpg',
#  'Mikhail_Shvydkoi_0001.jpg',
#  'Alan_Zemaitis_0001.jpg',
#  'John_Sweeney_0001.jpg',
#  'George_W_Bush_0410.jpg',
#  'Robert_Wagner_0001.jpg',
#  'John_Negroponte_0008.jpg',
#  'Rick_Wagoner_0001.jpg',
#  'Serena_Williams_0008.jpg',
#  'Carlos_Moya_0012.jpg',
#  'John_F_Kennedy_Jr_0002.jpg',
#  'Billy_Sollie_0001.jpg',
#  'Colin_Powell_0091.jpg',
#  'Elizabeth_Taylor_0002.jpg',
#  'George_W_Bush_0382.jpg',
#  'Enrik_Vendt_0001.jpg',
#  'Gian_Marco_0002.jpg',
#  'John_Paul_II_0005.jpg',
#  'Terry_Lynn_Barton_0001.jpg',
#  'Justin_Timberlake_0006.jpg',
#  'Jose_Maria_Aznar_0007.jpg',
#  'Noelle_Bush_0004.jpg',
#  'Kemal_Dervis_0002.jpg',
#  'Bill_Gates_0012.jpg',
#  'Christine_Gregoire_0001.jpg',
#  'Stacy_Dragila_0001.jpg',
#  'Jim_Haslett_0001.jpg',
#  'Dan_Bartlett_0001.jpg',
#  'John_Brady_0001.jpg',
#  'Carly_Fiorina_0001.jpg',
#  'Colin_Montgomerie_0002.jpg',
#  'Jean-Pierre_Raffarin_0006.jpg',
#  'Dileep_76.jpg',
#  'HrithikRoshan_20.jpg',
#  'Justine_Pasek_0007.jpg',
#  'Frank_Dunham_Jr_0001.jpg',
#  'Ahmad_Masood_0002.jpg',
#  'Michael_Chiklis_0005.jpg',
#  'Michael_Bloomberg_0004.jpg',
#  'Mohamed_ElBaradei_0003.jpg',
#  'Richard_Reid_0001.jpg',
#  'HrithikRoshan_149.jpg',
#  'Sergei_Yushenkov_0001.jpg',
#  'Pedro_Solbes_0004.jpg',
#  'Jacques_Chirac_0024.jpg',
#  'Jean_Chretien_0005.jpg',
#  'Abraham_Foxman_0001.jpg',
#  'Susan_Collins_0001.jpg',
#  'Mick_Jagger_0005.jpg',
#  'Andre_Agassi_0034.jpg',
#  'George_W_Bush_0400.jpg',
#  'Robert_Zoellick_0004.jpg',
#  'Luiz_Inacio_Lula_da_Silva_0010.jpg',
#  'George_W_Bush_0332.jpg',
#  'Edward_Said_0002.jpg',
#  'Fabrice_Santoro_0002.jpg',
#  'Riek_Blanjaar_0001.jpg',
#  'Leigh_Winchell_0001.jpg',
#  'Alexandra_Stevenson_0003.jpg',
#  'Jennifer_Garner_0011.jpg',
#  'Enrique_Bolanos_0002.jpg',
#  'Geraldine_Chaplin_0001.jpg',
#  'Eddie_Sutton_0001.jpg',
#  'Jean_Charest_0004.jpg',
#  'Julianne_Moore_0015.jpg',
#  'Christopher_Reeve_0003.jpg',
#  'Ricardo_Sanchez_0005.jpg',
#  'Recep_Tayyip_Erdogan_0015.jpg',
#  'Ben_Affleck_0004.jpg',
#  'KatrinaKaif_55.jpg',
#  'Joshua_Gracin_0001.jpg',
#  'Shigeo_Nagashima_0001.jpg',
#  'Tony_Blair_0092.jpg',
#  'Yossi_Beilin_0001.jpg',
#  'Jim_Spinoza_0001.jpg',
#  'Gregory_Peck_0001.jpg',
#  'Howard_Dean_0010.jpg',
#  'Michelle_Yeoh_0004.jpg',
#  'Joschka_Fischer_0001.jpg',
#  'Charles_Bell_0001.jpg',
#  'Toni_Jennings_0001.jpg',
#  'Jonathan_Mostow_0001.jpg',
#  'Bill_Clinton_0005.jpg',
#  'HrithikRoshan_145.jpg',
#  'Edmund_Stoiber_0003.jpg',
#  'Queen_Elizabeth_II_0002.jpg',
#  'Michael_Jordan_0001.jpg',
#  'Kofi_Annan_0021.jpg',
#  'John_Ashcroft_0027.jpg',
#  'Jacques_Rogge_0007.jpg',
#  'Martina_Hingis_0003.jpg',
#  'Akhmed_Zakayev_0003.jpg',
#  'Darrell_Royal_0001.jpg',
#  'Meles_Zenawi_0001.jpg',
#  'Sergio_Vieira_De_Mello_0009.jpg',
#  'FaridaJalal_51.jpg',
#  'KatrinaKaif_95.jpg',
#  'Alfonso_Soriano_0001.jpg',
#  'Shane_Phillips_0001.jpg',
#  'Boris_Becker_0002.jpg',
#  'Donald_Rumsfeld_0077.jpg',
#  'Diego_Diego_Lerman_0001.jpg',
#  'Mahathir_Mohamad_0013.jpg',
#  'Gerhard_Schroeder_0037.jpg',
#  'Brenda_Wilson_0001.jpg',
#  'Donna_Walker_0001.jpg',
#  'Paris_Hilton_0001.jpg',
#  'John_Bolton_0003.jpg',
#  'Jennifer_Capriati_0034.jpg',
#  'Nancy_Pelosi_0012.jpg',
#  'Gerhard_Schroeder_0036.jpg',
#  'HrithikRoshan_79.jpg',
#  'Sourav_Ganguly_0002.jpg',
#  'FaridaJalal_89.jpg',
#  'Roy_Moore_0001.jpg',
#  'Tony_Blair_0132.jpg',
#  'Katherine_Harris_0001.jpg',
#  'Nestor_Kirchner_0026.jpg',
#  'Junichiro_Koizumi_0060.jpg',
#  'Clint_Eastwood_0006.jpg',
#  'Colin_Powell_0137.jpg',
#  'Matthew_During_0001.jpg',
#  'Olesya_Bonabarenko_0001.jpg',
#  'George_Lopez_0003.jpg',
#  'Jens_Lehmann_0001.jpg',
#  'Pamela_Anderson_0001.jpg',
#  'Juan_Ignacio_Chela_0003.jpg',
#  'Jennifer_Furminger_0001.jpg',
#  'Colin_Farrell_0007.jpg',
#  'Mohamed_ElBaradei_0005.jpg',
#  'Colin_Campbell_0001.jpg',
#  'Ariel_Sharon_0045.jpg',
#  'Colin_Powell_0023.jpg',
#  'George_W_Bush_0002.jpg',
#  'Billy_Crystal_0001.jpg',
#  'Tom_OBrien_0001.jpg',
#  'John_Sununu_0001.jpg',
#  'Jennifer_Lopez_0016.jpg',
#  'Rob_Lowe_0001.jpg',
#  'Esther_Macklin_0001.jpg',
#  'Amelia_Vega_0001.jpg',
#  'FaridaJalal_17.jpg',
#  'Rosario_Dawson_0001.jpg',
#  'Venus_Williams_0016.jpg',
#  'Peter_Mullan_0001.jpg',
#  'Saddam_Hussein_0011.jpg',
#  'David_Heyman_0002.jpg',
#  'Alfred_Sant_0001.jpg',
#  'Mary_Lou_Markakis_0001.jpg',
#  'Ray_Liotta_0001.jpg',
#  'Elena_Likhovtseva_0001.jpg',
#  'Raoul_Ruiz_0003.jpg',
#  'Mariana_Ohata_0001.jpg',
#  'Michael_Capellas_0002.jpg',
#  'Jacques_Chirac_0020.jpg',
#  'John_Abizaid_0005.jpg',
#  'Ben_Affleck_0001.jpg',
#  'Jerry_Regier_0004.jpg',
#  'Kurt_Schottenheimer_0001.jpg',
#  'Rebecca_Romijn-Stamos_0002.jpg',
#  'Ronald_Brower_0001.jpg',
#  'Paul_ONeill_0007.jpg',
#  'Norah_Jones_0007.jpg',
#  'Barbara_Esbin_0001.jpg',
#  'Prince_Philippe_0001.jpg',
#  'Tony_Blair_0096.jpg',
#  'Bill_Clinton_0028.jpg',
#  'Nadia_Petrova_0005.jpg',
#  'Gary_Williams_0001.jpg',
#  'Paul_Wolfowitz_0007.jpg',
#  'Paul_Patton_0001.jpg',
#  'Britney_Spears_0002.jpg',
#  'Michael_Moore_0001.jpg',
#  'Bertie_Ahern_0003.jpg',
#  'Picabo_Street_0001.jpg',
#  'Serena_Williams_0036.jpg',
#  'Kirk_Doerger_0001.jpg',
#  'Jean-Sebastien_Giguere_0001.jpg',
#  'Jean-Francois_Lemounier_0001.jpg',
#  'Julianne_Moore_0008.jpg',
#  'Tang_Jiaxuan_0001.jpg',
#  'Hana_Sadiq_0001.jpg',
#  'George_W_Bush_0529.jpg',
#  'George_W_Bush_0078.jpg',
#  'Joseph_LePore_0001.jpg',
#  'Zhu_Rongji_0005.jpg',
#  'Charles_Moose_0002.jpg',
#  'Valeri_Bure_0001.jpg',
#  'Ben_Davis_0001.jpg',
#  'Hipolito_Mejia_0004.jpg',
#  'Nestor_Kirchner_0010.jpg',
#  'Gabriel_Valdes_0001.jpg',
#  'Hung_Wan-ting_0001.jpg',
#  'Elsa_Zylberstein_0002.jpg',
#  'Warren_Beatty_0001.jpg',
#  'James_Butts_0002.jpg',
#  'Ludivine_Sagnier_0002.jpg',
#  'Alyse_Beaupre_0001.jpg',
#  'Tom_Harkin_0004.jpg',
#  'Ana_Guevara_0006.jpg',
#  'Tony_Clement_0001.jpg',
#  'Jonathan_Edwards_0004.jpg',
#  'Guillermo_Canas_0001.jpg',
#  'George_W_Bush_0286.jpg',
#  'Howard_Schultz_0001.jpg',
#  'Fabricio_Oberto_0001.jpg',
#  'Gillian_Anderson_0002.jpg',
#  'William_Cocksedge_0001.jpg',
#  'Tony_Blair_0001.jpg',
#  'Jerry_Pauley_0001.jpg',
#  'Hans_Blix_0022.jpg',
#  'Matthew_Perry_0005.jpg',
#  'Chip_Knight_0001.jpg',
#  'Andre_Agassi_0003.jpg',
#  'Steve_Spurrier_0001.jpg',
#  'Ariel_Sharon_0077.jpg',
#  'Barbara_Becker_0001.jpg',
#  'Abdullah_0002.jpg',
#  'Vicente_Fox_0013.jpg',
#  'Gary_Leon_Ridgway_0001.jpg',
#  'Brian_Campbell_0001.jpg',
#  'Mstislav_Rostropovich_0001.jpg',
#  'Gerhard_Schroeder_0070.jpg',
#  'HrithikRoshan_13.jpg',
#  'Carlos_Menem_0005.jpg',
#  'James_Brazelton_0001.jpg',
#  'Colin_Jackson_0002.jpg',
#  'Roh_Moo-hyun_0032.jpg',
#  'Chandrika_Kumaratunga_0001.jpg',
#  'Juan_Carlos_Ferrero_0017.jpg',
#  'George_W_Bush_0299.jpg',
#  'John_Manley_0006.jpg',
#  'Joseph_Blatter_0002.jpg',
#  'Charlton_Heston_0006.jpg',
#  'Natalie_Cole_0002.jpg',
#  'George_W_Bush_0159.jpg',
#  'Jeff_Van_Gundy_0002.jpg',
#  'Jim_Tressel_0003.jpg',
#  'Gerald_Barbarito_0001.jpg',
#  'Renee_Zellweger_0017.jpg',
#  'Oscar_De_La_Hoya_0003.jpg',
#  'Kurt_Hellstrom_0001.jpg',
#  'Donald_Rumsfeld_0040.jpg',
#  'KatrinaKaif_68.jpg',
#  'Jennifer_Lopez_0015.jpg',
#  'Justine_Henin_0001.jpg',
#  'Steve_Pagliuca_0001.jpg',
#  'Rick_Barnes_0002.jpg',
#  'Keith_Bishop_Jr_0001.jpg',
#  'Jimmy_Smits_0001.jpg',
#  'Ludivine_Sagnier_0005.jpg',
#  'George_W_Bush_0093.jpg',
#  'Avinash_29.jpg',
#  'Serena_Williams_0001.jpg',
#  'Heidi_Fleiss_0004.jpg',
#  'Lisa_Marie_Presley_0002.jpg',
#  'Kelli_White_0001.jpg',
#  'Cate_Blanchett_0003.jpg',
#  'Michael_Bloomberg_0016.jpg',
#  'Terence_Newman_0001.jpg',
#  'Heather_Whitestone_McCallum_0001.jpg',
#  'Tony_Blair_0114.jpg',
#  'James_Blake_0001.jpg',
#  'HrithikRoshan_161.jpg',
#  'Maria_Soledad_Alvear_Valenzuela_0005.jpg',
#  'Colin_Powell_0150.jpg',
#  'John_Ashcroft_0005.jpg',
#  'William_Macy_0003.jpg',
#  'Gloria_Macapagal_Arroyo_0005.jpg',
#  'Percy_Gibson_0001.jpg',
#  'Anders_Ebbeson_0001.jpg',
#  'Cyndi_Thompson_0002.jpg',
#  'Jeremy_Fogel_0001.jpg',
#  'Kate_Winslet_0003.jpg',
#  'George_W_Bush_0035.jpg',
#  'Andres_Manuel_Lopez_Obrador_0001.jpg',
#  'Lester_Holt_0001.jpg',
#  'Kim_Clijsters_0005.jpg',
#  'Marwan_Barghouthi_0001.jpg',
#  'Maryn_McKenna_0001.jpg',
#  'Sarah_Michelle_Gellar_0003.jpg',
#  'Max_von_Sydow_0001.jpg',
#  'Cesar_Gaviria_0002.jpg',
#  'Arminio_Fraga_0003.jpg',
#  'Tyler_Hamilton_0002.jpg',
#  'Patti_Labelle_0001.jpg',
#  'William_Martin_0002.jpg',
#  'Gustavo_Kuerten_0003.jpg',
#  'Gwyneth_Paltrow_0001.jpg',
#  'George_W_Bush_0458.jpg',
#  'Nicole_Kidman_0015.jpg',
#  'Mike_Farrar_0001.jpg',
#  'Wen_Jiabao_0011.jpg',
#  'Caroline_Kennedy_0002.jpg',
#  'Joe_Calzaghe_0002.jpg',
#  'Donald_Rumsfeld_0072.jpg',
#  'Rick_Dinse_0003.jpg',
#  'Al_Sharpton_0007.jpg',
#  'Jayamadhuri_59.jpg',
#  'Hosni_Mubarak_0006.jpg',
#  'Guillermo_Ruiz_Polanco_0001.jpg',
#  'Mark_Philippoussis_0005.jpg',
#  'Robert_Duvall_0005.jpg',
#  'Derek_Jeter_0004.jpg',
#  'Marcella_Anderson_0001.jpg',
#  'Lleyton_Hewitt_0009.jpg',
#  'Colin_Powell_0139.jpg',
#  'Tom_Osborne_0001.jpg',
#  'Jennifer_Capriati_0027.jpg',
#  'Shinzo_Abe_0001.jpg',
#  'Jennifer_Lopez_0008.jpg',
#  'Edouard_Michelin_0001.jpg',
#  'Horst_Koehler_0001.jpg',
#  'Paul_Wolfowitz_0001.jpg',
#  'Mohammad_Khatami_0009.jpg',
#  'Dileep_72.jpg',
#  'Catherine_Zeta-Jones_0009.jpg',
#  'Daniel_Ortega_0001.jpg',
#  'Colin_Powell_0217.jpg',
#  'Sean_Astin_0002.jpg',
#  'Paris_Hilton_0002.jpg',
#  'Mahmoud_Diyab_al-Ahmed_0001.jpg',
#  'Dan_Morales_0002.jpg',
#  'Brad_Wilk_0001.jpg',
#  'Jayamadhuri_175.jpg',
#  'Lorraine_Bracco_0001.jpg',
#  'Jeremy_Greenstock_0003.jpg',
#  'Michelle_Yeoh_0003.jpg',
#  'Paradorn_Srichaphan_0008.jpg',
#  'Ariel_Sharon_0014.jpg',
#  'George_W_Bush_0371.jpg',
#  'FaridaJalal_50.jpg',
#  'Jacques_Chirac_0031.jpg',
#  'Charlton_Heston_0003.jpg',
#  'Barbra_Streisand_0001.jpg',
#  'Leuris_Pupo_0001.jpg',
#  'Lou_Piniella_0002.jpg',
#  'Sureyya_Ayhan_0001.jpg',
#  'Edmund_Stoiber_0013.jpg',
#  'Gerhard_Schroeder_0029.jpg',
#  'Tommy_Thompson_0002.jpg',
#  'Jennifer_Garner_0012.jpg',
#  'Clay_Campbell_0001.jpg',
#  'Owen_Nolan_0001.jpg',
#  'Fred_Eckhard_0002.jpg',
#  'Tony_Blair_0003.jpg',
#  'Laura_Bush_0017.jpg',
#  'Laura_Morante_0001.jpg',
#  'George_W_Bush_0421.jpg',
#  'Sue_Guevara_0001.jpg',
#  'Larry_Brown_0007.jpg',
#  'Hans_Blix_0015.jpg',
#  'Ariel_Sharon_0002.jpg',
#  'Sebastien_Grosjean_0001.jpg',
#  'Lino_Oviedo_0003.jpg',
#  'Svend_Aage_Jensby_0001.jpg',
#  'Dolly_Parton_0001.jpg',
#  'Jayamadhuri_185.jpg',
#  'Gordon_Brown_0013.jpg',
#  'Jennifer_Capriati_0039.jpg',
#  'Tom_Coverdale_0002.jpg',
#  'Junichiro_Koizumi_0003.jpg',
#  'Luke_Walton_0002.jpg',
#  'Jerry_Jones_0001.jpg',
#  'Michael_Richards_0001.jpg',
#  'Stanley_Ho_0001.jpg',
#  'George_W_Bush_0122.jpg',
#  'Dominique_de_Villepin_0006.jpg',
#  'Nancy_Sinatra_0002.jpg',
#  'Naji_Sabri_0008.jpg',
#  'George_W_Bush_0013.jpg',
#  'Steve_Wariner_0001.jpg',
#  'David_McKiernan_0001.jpg',
#  'Antonio_Banderas_0004.jpg',
#  'Richard_Levin_0001.jpg',
#  'Carlos_Manuel_Pruneda_0002.jpg',
#  'John_Malkovich_0002.jpg',
#  'Joe_Lieberman_0010.jpg',
#  'Michelle_Kwan_0007.jpg',
#  'Antonio_Palocci_0005.jpg',
#  'Roman_Polanski_0002.jpg',
#  'Barbora_Strycova_0001.jpg',
#  'Bob_Menendez_0001.jpg',
#  'Roger_Federer_0006.jpg',
#  'George_W_Bush_0034.jpg',
#  'Silvio_Berlusconi_0033.jpg',
#  'Ralf_Schumacher_0004.jpg',
#  'Donald_Rumsfeld_0034.jpg',
#  'George_W_Bush_0158.jpg',
#  'Ariel_Sharon_0068.jpg',
#  'Ryan_Leaf_0001.jpg',
#  'Carol_Moseley_Braun_0002.jpg',
#  'Serena_Williams_0035.jpg',
#  'Estelle_Morris_0001.jpg',
#  'Jamie_Martin_0001.jpg',
#  'Carl_Pope_0001.jpg',
#  'Lynn_Redgrave_0001.jpg',
#  'Noor_Mohammed_0001.jpg',
#  'Kjell_Magne_Bondevik_0001.jpg',
#  'George_Brumley_III_0001.jpg',
#  'Ron_Dittemore_0002.jpg',
#  'Tim_Robbins_0001.jpg',
#  'Marieta_Chrousala_0002.jpg',
#  'Luiz_Inacio_Lula_da_Silva_0016.jpg',
#  'Carlos_Savedra_0001.jpg',
#  'Laura_Bush_0004.jpg',
#  'McGuire_Gibson_0001.jpg',
#  'Javier_Delgado_0001.jpg',
#  'Leslie_Ann_Woodward_0001.jpg',
#  'Todd_Reid_0001.jpg',
#  'Gregg_Berhalter_0001.jpg',
#  'Kim_Ryong-sung_0002.jpg',
#  'Catherine_Zeta-Jones_0002.jpg',
#  'Hannah_Stockbauer_0002.jpg',
#  'Nicole_Kidman_0012.jpg',
#  'Martin_McGuinness_0005.jpg',
#  'Qian_Qichen_0001.jpg',
#  'KatrinaKaif_66.jpg',
#  'Mike_Scioscia_0001.jpg',
#  'Amelie_Mauresmo_0006.jpg',
#  'Junichiro_Koizumi_0059.jpg',
#  'George_Clooney_0007.jpg',
#  'Moon-So-ri_0001.jpg',
#  'Norah_Jones_0011.jpg',
#  'Jackie_Chan_0005.jpg',
#  'Richard_Norton-Taylor_0001.jpg',
#  'Paul_Wolfowitz_0005.jpg',
#  'Steven_Curtis_Chapman_0001.jpg',
#  'Lisa_Murkowski_0001.jpg',
#  'Lyle_Vanclief_0002.jpg',
#  'Jim_Letten_0001.jpg',
#  'Colin_Powell_0001.jpg',
#  'Angelina_Jolie_0019.jpg',
#  'Muffet_McGraw_0001.jpg',
#  'Alvaro_Silva_Calderon_0001.jpg',
#  'Bryce_Carmine_0001.jpg',
#  'John_Mayer_0002.jpg',
#  'Inga_Hall_0001.jpg',
#  'Lela_Rochon_0001.jpg',
#  'Franco_Cangele_0001.jpg',
#  'Carlos_De_Abreu_0001.jpg',
#  'Simona_Hradil_0001.jpg',
#  'Matt_Dillon_0003.jpg',
#  'Brendan_Hansen_0001.jpg',
#  'HrithikRoshan_44.jpg',
#  'Dolly_Parton_0002.jpg',
#  'Ed_Rendell_0001.jpg',
#  'James_Wallack_0001.jpg',
#  'Alejandro_Toledo_0013.jpg',
#  'HrithikRoshan_6.jpg',
#  'Donald_Rumsfeld_0013.jpg',
#  'Sila_Calderon_0003.jpg',
#  'Colin_Powell_0065.jpg',
#  'Jennifer_Capriati_0028.jpg',
#  'George_W_Bush_0411.jpg',
#  'Tony_Blair_0055.jpg',
#  'Tony_Blair_0031.jpg',
#  'Donna_Morrissey_0001.jpg',
#  'Colin_Powell_0049.jpg',
#  'Bill_Simon_0015.jpg',
#  'Jon_Corzine_0001.jpg',
#  'Gerhard_Schroeder_0047.jpg',
#  'Tom_Daschle_0019.jpg',
#  'Michael_Clarke_Duncan_0001.jpg',
#  'Francisco_Maturana_0001.jpg',
#  'Fruit_Chan_0001.jpg',
#  'Recep_Tayyip_Erdogan_0003.jpg',
#  'Jennifer_Rodriguez_0002.jpg',
#  'Jason_Sorens_0001.jpg',
#  'Mehmet_Ali_Sahin_0001.jpg',
#  'Maria_Simon_0001.jpg',
#  'Colin_Powell_0015.jpg',
#  'Ozzy_Osbourne_0002.jpg',
#  'Gerhard_Schroeder_0020.jpg',
#  'Bruna_Colosio_0001.jpg',
#  'William_Delahunt_0001.jpg',
#  'Tom_Daschle_0008.jpg',
#  'Saddam_Hussein_0001.jpg',
#  'Bob_Cantrell_0001.jpg',
#  'Richard_Krajicek_0001.jpg',
#  'Jacques_Kallis_0001.jpg',
#  'Geoff_Hoon_0001.jpg',
#  'Antonio_Banderas_0002.jpg',
#  'George_W_Bush_0412.jpg',
#  'Dileep_101.jpg',
#  'Ismael_Miranda_0001.jpg',
#  'Colin_Powell_0106.jpg',
#  'Carla_Del_Ponte_0003.jpg',
#  'Reese_Witherspoon_0004.jpg',
#  'Francesco_Totti_0001.jpg',
#  'SharmilaTagore_39.jpg',
#  'John_Moxley_0001.jpg',
#  'David_Beckham_0017.jpg',
#  'Salma_Hayek_0001.jpg',
#  'Carlos_Menem_0001.jpg',
#  'Mick_Jagger_0004.jpg',
#  'Hans_Blix_0033.jpg',
#  'Edmund_Stoiber_0004.jpg',
#  'Ricardo_Mayorga_0001.jpg',
#  'Dileep_110.jpg',
#  'Silvio_Berlusconi_0001.jpg',
#  'George_W_Bush_0302.jpg',
#  'Nawabzada_Nasrullah_Khan_0001.jpg',
#  'Paul_Burrell_0011.jpg',
#  'Andre_Agassi_0031.jpg',
#  'Kai-Uwe_Ricke_0001.jpg',
#  'Dwarakish_139.jpg',
#  'SharmilaTagore_29.jpg',
#  'David_Trimble_0005.jpg',
#  'Peter_Shaw_0001.jpg',
#  'Jerry_Sloan_0001.jpg',
#  'Gerhard_Schroeder_0087.jpg',
#  'Don_Boudria_0001.jpg',
#  'George_W_Bush_0199.jpg',
#  'David_Beckham_0019.jpg',
#  'KatrinaKaif_60.jpg',
#  'Trent_Lott_0004.jpg',
#  'Juan_Carlos_Ferrero_0023.jpg',
#  'Manfred_Stolpe_0001.jpg',
#  'HrithikRoshan_67.jpg',
#  'Ken_Dorsey_0001.jpg',
#  'Pete_Sampras_0015.jpg',
#  'Lou_Piniella_0003.jpg',
#  'Mike_Johanns_0001.jpg',
#  'HrithikRoshan_22.jpg',
#  'Rainer_Schuettler_0005.jpg',
#  'Colleen_Ryan_0001.jpg',
#  'Mohammed_Ashraf_Hafiz_0001.jpg',
#  'Kenny_Chesney_0001.jpg',
#  'Donald_Keck_0001.jpg',
#  'Rick_Romley_0003.jpg',
#  'Jim_Ahern_0001.jpg',
#  'Nestor_Kirchner_0012.jpg',
#  'John_Gordnick_0001.jpg',
#  'Christine_Rau_0001.jpg',
#  'Gerhard_Schroeder_0058.jpg',
#  'Lana_Clarkson_0002.jpg',
#  'Brian_Heidik_0001.jpg',
#  'Courtney_Love_0002.jpg',
#  'Isaiah_Washington_0001.jpg',
#  'Sharon_Osbourne_0002.jpg',
#  'George_Clooney_0002.jpg',
#  'Mark_Hurlbert_0002.jpg',
#  'George_W_Bush_0454.jpg',
#  'Eduardo_Duhalde_0011.jpg',
#  'Richard_Branson_0001.jpg',
#  'Muhammad_Ali_0005.jpg',
#  'Nelson_Mandela_0001.jpg',
#  'Jayamadhuri_18.jpg',
#  'Chris_Byrd_0001.jpg',
#  'Osrat_Iosef_0001.jpg',
#  'Mahmoud_Abbas_0027.jpg',
#  'Theo_Angelopoulos_0001.jpg',
#  'George_McCloud_0001.jpg',
#  'Jeong_Se-hyun_0006.jpg',
#  'Lorne_Michaels_0001.jpg',
#  'Tim_Curry_0001.jpg',
#  'Catherine_Bell_0001.jpg',
#  'SharmilaTagore_76.jpg',
#  'Larry_Lindsey_0001.jpg',
#  'Tommy_Franks_0013.jpg',
#  'Terunobu_Maeda_0001.jpg',
#  'George_W_Bush_0019.jpg',
#  'Lin_Yi-fu_0001.jpg',
#  'George_W_Bush_0413.jpg',
#  'Roh_Moo-hyun_0022.jpg',
#  'Ben_Glisan_0002.jpg',
#  'Atal_Bihari_Vajpayee_0015.jpg',
#  'Gloria_Macapagal_Arroyo_0031.jpg',
#  'John_Howard_0016.jpg',
#  'George_Robertson_0008.jpg',
#  'Jesse_Jackson_0002.jpg',
#  'Tony_Blair_0004.jpg',
#  'Rick_Carlisle_0004.jpg',
#  'Colin_Powell_0110.jpg',
#  'Andre_Agassi_0013.jpg',
#  'Jayamadhuri_141.jpg',
#  'Diane_Green_0002.jpg',
#  'George_W_Bush_0001.jpg',
#  'Martin_McCauley_0001.jpg',
#  'Mitchell_Swartz_0001.jpg',
#  'Oleksandr_Moroz_0001.jpg',
#  'Atal_Bihari_Vajpayee_0014.jpg',
#  'Hilary_Duff_0001.jpg',
#  'Mike_Krzyzewski_0006.jpg',
#  'Guillermo_Coria_0028.jpg',
#  'Missy_Crider_0001.jpg',
#  'Eli_Stutsman_0001.jpg',
#  'Nestor_Kirchner_0020.jpg',
#  'Meryl_Streep_0011.jpg',
#  'Dwarakish_32.jpg',
#  'Jose_Maria_Aznar_0015.jpg',
#  'Wayne_Ferreira_0002.jpg',
#  'Marcus_Allen_0001.jpg',
#  'JK_Rowling_0003.jpg',
#  'Paul_William_Hurley_0002.jpg',
#  'Roh_Moo-hyun_0017.jpg',
#  'Gerhard_Schroeder_0055.jpg',
#  'Jayamadhuri_191.jpg',
#  'Carolyn_Dawn_Johnson_0001.jpg',
#  'Gary_Doer_0003.jpg',
#  'George_W_Bush_0430.jpg',
#  'SharmilaTagore_71.jpg',
#  'Steve_Backley_0001.jpg',
#  'Gloria_Macapagal_Arroyo_0008.jpg',
#  'Javier_Weber_0002.jpg',
#  'Boris_Becker_0005.jpg',
#  'Cesar_Gaviria_0006.jpg',
#  'Don_Henley_0001.jpg',
#  'Mike_Helton_0002.jpg',
#  'Ricky_Ponting_0002.jpg',
#  'SharmilaTagore_15.jpg',
#  'Tony_Blair_0044.jpg',
#  'Nicolas_Escude_0001.jpg',
#  'Cecilia_Bolocco_0003.jpg',
#  'Lucy_Liu_0003.jpg',
#  'Harry_Belafonte_0002.jpg',
#  'Taha_Yassin_Ramadan_0010.jpg',
#  'George_W_Bush_0091.jpg',
#  'Hans_Blix_0032.jpg',
#  'Nestor_Kirchner_0028.jpg',
#  'Alejandro_Lerner_0001.jpg',
#  'Leslie_Caldwell_0001.jpg',
#  'Jiang_Zemin_0001.jpg',
#  'Hal_Gehman_0001.jpg',
#  'George_W_Bush_0142.jpg',
#  'Edward_Lu_0004.jpg',
#  'Manfred_Reyes_Villa_0001.jpg',
#  'Arnold_Schwarzenegger_0012.jpg',
#  'Matt_Morris_0001.jpg',
#  'Hugo_Chavez_0006.jpg',
#  'Tony_Stewart_0005.jpg',
#  'Dave_Williams_0001.jpg',
#  'Jayamadhuri_96.jpg',
#  'Heath_Ledger_0004.jpg',
#  'Tim_Duncan_0003.jpg',
#  'Elias_Attallah_0001.jpg',
#  'Donald_Rumsfeld_0071.jpg',
#  'Naomi_Campbell_0001.jpg',
#  'Mark_Philippoussis_0004.jpg',
#  'Tony_Blair_0106.jpg',
#  'Naomi_Watts_0017.jpg',
#  'Hugo_Chavez_0026.jpg',
#  'Alison_Lohman_0001.jpg',
#  'Chris_Klein_0001.jpg',
#  'Eliane_Karp_0003.jpg',
#  'Joseph_Ralston_0001.jpg',
#  'Don_Siegelman_0001.jpg',
#  'Martha_Burk_0002.jpg',
#  'Tony_Blair_0135.jpg',
#  'George_Pataki_0001.jpg',
#  'Paul_Murphy_0001.jpg',
#  'Prince_Willem-Alexander_0003.jpg',
#  'Gerhard_Schroeder_0002.jpg',
#  'Igor_Trunov_0001.jpg',
#  'Oswaldo_Paya_0001.jpg',
#  'FaridaJalal_30.jpg',
#  'Lindsay_Davenport_0009.jpg',
#  'Mike_Weir_0007.jpg',
#  'Lily_Tomlin_0001.jpg',
#  'Michael_Bloomberg_0009.jpg',
#  'Chick_Hearn_0001.jpg',
#  'Elvis_Presley_0002.jpg',
#  'Bob_Petrino_0001.jpg',
#  'John_Allen_Muhammad_0001.jpg',
#  'John_Warner_0003.jpg',
#  'Sivan_Klein_0001.jpg',
#  'Edgar_Savisaar_0001.jpg',
#  'Steve_Nash_0001.jpg',
#  'Paul_Byrd_0002.jpg',
#  'Tony_Blair_0128.jpg',
#  'Gianna_Angelopoulos-Daskalaki_0001.jpg',
#  'King_Abdullah_II_0002.jpg',
#  'Kofi_Annan_0014.jpg',
#  'Jada_Pinkett_Smith_0002.jpg',
#  'Michael_Douglas_0003.jpg',
#  'Tommy_Thompson_0004.jpg',
#  'Sepp_Blatter_0002.jpg',
#  'Laura_Bush_0023.jpg',
#  'Hosni_Mubarak_0004.jpg',
#  'Yves_Brodeur_0001.jpg',
#  'Dennis_Hastert_0001.jpg',
#  'Gloria_Macapagal_Arroyo_0038.jpg',
#  'Dominique_de_Villepin_0007.jpg',
#  'Rob_Marshall_0006.jpg',
#  'Clint_Eastwood_0001.jpg',
#  'Charlie_Williams_0001.jpg',
#  'Tatiana_Shchegoleva_0001.jpg',
#  'Gene_Robinson_0005.jpg',
#  'Askar_Akayev_0001.jpg',
#  'Daniel_Comisso_Urdaneta_0001.jpg',
#  'Amelie_Mauresmo_0005.jpg',
#  'Donald_Rumsfeld_0099.jpg',
#  'Sean_Townsend_0001.jpg',
#  'Jose_Maria_Aznar_0009.jpg',
#  'Fran_Drescher_0001.jpg',
#  'Claudio_Ranieri_0001.jpg',
#  'Franklin_Damann_0001.jpg',
#  'Bill_Belichick_0001.jpg',
#  'Jayamadhuri_205.jpg',
#  'Christian_Gimenez_0001.jpg',
#  'Jean-Pierre_Raffarin_0001.jpg',
#  'Recep_Tayyip_Erdogan_0022.jpg',
#  'KatrinaKaif_62.jpg',
#  'Darko_Milicic_0001.jpg',
#  'Colin_Powell_0206.jpg',
#  'Mahathir_Mohamad_0010.jpg',
#  'Vinnie_Jones_0001.jpg',
#  'Jose_Miguel_Aleman_0001.jpg',
#  'Darrell_Dickey_0001.jpg',
#  'Vladimir_Putin_0022.jpg',
#  'Cyndi_Thompson_0001.jpg',
#  'George_W_Bush_0456.jpg',
#  'Michael_Powell_0003.jpg',
#  'Nikki_Reed_0002.jpg',
#  'Judd_Davies_0001.jpg',
#  'Hugo_Chavez_0055.jpg',
#  'Hedayat_Amin_Arsala_0001.jpg',
#  'Jean_Chretien_0050.jpg',
#  'Edward_Lu_0003.jpg',
#  'Hamid_Karzai_0016.jpg',
#  'Colin_Powell_0117.jpg',
#  'Laura_Bush_0022.jpg',
#  'Jayamadhuri_105.jpg',
#  'John_Paul_II_0001.jpg',
#  'Fernando_Henrique_Cardoso_0005.jpg',
#  'Linda_Lingle_0001.jpg',
#  'George_Roy_Hill_0001.jpg',
#  'Dwarakish_61.jpg',
#  'Andrei_Mikhnevich_0002.jpg',
#  'Joe_Lieberman_0005.jpg',
#  'Norodom_Sihanouk_0001.jpg',
#  'Gloria_Macapagal_Arroyo_0034.jpg',
#  'Oleg_Romantsev_0001.jpg',
#  'Dennis_Powell_0001.jpg',
#  'Joey_Buttafuoco_0001.jpg',
#  'Steve_Park_0002.jpg',
#  'Gillian_Anderson_0001.jpg',
#  'Pamela_Anderson_0002.jpg',
#  'Carmen_Electra_0004.jpg',
#  'Avinash_27.jpg',
#  'George_W_Bush_0118.jpg',
#  'Angelina_Jolie_0002.jpg',
#  'Magui_Serna_0002.jpg',
#  'Luiz_Inacio_Lula_da_Silva_0013.jpg',
#  'Dwarakish_176.jpg',
#  'Ashlea_Talbot_0001.jpg',
#  'Colin_Powell_0135.jpg',
#  'Angelina_Jolie_0009.jpg',
#  'Federico_Trillo_0001.jpg',
#  'Gerhard_Schroeder_0010.jpg',
#  'Mahmoud_Abbas_0018.jpg',
#  'Angelina_Jolie_0010.jpg',
#  'Jayamadhuri_190.jpg',
#  'Mel_Brooks_0001.jpg',
#  'Xavier_Malisse_0003.jpg',
#  'Robert_Zoellick_0005.jpg',
#  'Rachel_Hunter_0003.jpg',
#  'Alvaro_Uribe_0028.jpg',
#  'Robert_Witt_0002.jpg',
#  'Jackie_Chan_0011.jpg',
#  'Jacques_Rogge_0003.jpg',
#  'Mike_Maroth_0001.jpg',
#  'Guillermo_Coria_0003.jpg',
#  'Charlotte_Church_0001.jpg',
#  'Karin_Viard_0001.jpg',
#  'Patricia_Wartusch_0001.jpg',
#  'Ricky_Barnes_0002.jpg',
#  'Jayamadhuri_53.jpg',
#  'Jennifer_Aniston_0017.jpg',
#  'Steven_Spielberg_0004.jpg',
#  'HrithikRoshan_197.jpg',
#  'John_Negroponte_0016.jpg',
#  'Mike_Tyson_0001.jpg',
#  'Evan_Rachel_Wood_0003.jpg',
#  'David_Stern_0001.jpg',
#  'Richard_Harris_0001.jpg',
#  'Alejandro_Toledo_0026.jpg',
#  'Hamid_Karzai_0020.jpg',
#  'Tom_Watson_0003.jpg',
#  'Eddie_Compass_0001.jpg',
#  'Laura_Bush_0028.jpg',
#  'Donald_Rumsfeld_0030.jpg',
#  'George_W_Bush_0216.jpg',
#  'HrithikRoshan_94.jpg',
#  'Avinash_2.jpg',
#  'Kofi_Annan_0016.jpg',
#  'John_Ashcroft_0021.jpg',
#  'Earl_Fritts_0001.jpg',
#  'Michael_Taylor_0001.jpg',
#  'John_Negroponte_0011.jpg',
#  'Howard_Dean_0006.jpg',
#  'Luis_Ernesto_Derbez_Bautista_0003.jpg',
#  'Mohammed_Salmane_0001.jpg',
#  'Dileep_54.jpg',
#  'Laura_Hernandez_0001.jpg',
#  'Jessica_Alba_0001.jpg',
#  'John_Stockton_0003.jpg',
#  'Gary_Dellaverson_0001.jpg',
#  'Rogerio_Romero_0001.jpg',
#  'Katie_Harman_0002.jpg',
#  'Tim_Floyd_0002.jpg',
#  'Paul_ONeill_0006.jpg',
#  'Hans_Blix_0013.jpg',
#  'Pete_Sampras_0018.jpg',
#  'Patrick_Leahy_0001.jpg',
#  'John_Negroponte_0027.jpg',
#  'George_W_Bush_0501.jpg',
#  'Lena_Katina_0001.jpg',
#  'Alan_Greenspan_0003.jpg',
#  'Martin_Howard_0001.jpg',
#  'John_Rowland_0002.jpg',
#  'Choi_Sung-hong_0005.jpg',
#  'Alan_Greenspan_0005.jpg',
#  'Gerhard_Schroeder_0044.jpg',
#  'Erika_Christensen_0001.jpg',
#  'Flavia_Pennetta_0001.jpg',
#  'Kurt_Warner_0005.jpg',
#  'Laura_Linney_0002.jpg',
#  'Ralf_Schumacher_0007.jpg',
#  'Renee_Zellweger_0011.jpg',
#  'Angelo_Reyes_0001.jpg',
#  'Julia_Ormond_0001.jpg',
#  'Manuel_Pellegrini_0001.jpg',
#  'George_W_Bush_0094.jpg',
#  'KatrinaKaif_14.jpg',
#  'Bobby_Jackson_0001.jpg',
#  'Tom_Hanks_0004.jpg',
#  'Rob_Schneider_0001.jpg',
#  'Jayamadhuri_146.jpg',
#  'John_Manley_0003.jpg',
#  'Lili_Taylor_0002.jpg',
#  'Lleyton_Hewitt_0013.jpg',
#  'Marwan_Muasher_0001.jpg',
#  'Igor_Ivanov_0015.jpg',
#  'Jonathan_Edwards_0008.jpg',
#  'Jennifer_Capriati_0019.jpg',
#  'Taku_Yamasaki_0001.jpg',
#  'Tony_Blair_0046.jpg',
#  'Viara_Vike-Freiberga_0001.jpg',
#  'Dileep_47.jpg',
#  'Dwarakish_129.jpg',
#  'Jayamadhuri_54.jpg',
#  'Ray_Allen_0001.jpg',
#  'Dorthy_Moxley_0001.jpg',
#  'Mohammed_Al-Douri_0013.jpg',
#  'Robert_Duvall_0008.jpg',
#  'Michael_Killeen_0001.jpg',
#  'Vanessa_Redgrave_0002.jpg',
#  'Kajsa_Bergqvist_0001.jpg',
#  'Hermando_Harton_0001.jpg',
#  'Paula_Dobriansky_0001.jpg',
#  'Elton_John_0007.jpg',
#  'Fatmir_Limaj_0001.jpg',
#  'Tom_Craddick_0004.jpg',
#  'Junichiro_Koizumi_0020.jpg',
#  'Winona_Ryder_0010.jpg',
#  'KatrinaKaif_44.jpg',
#  'SharmilaTagore_42.jpg',
#  'Chanda_Rubin_0002.jpg',
#  'FaridaJalal_69.jpg',
#  'Thomas_Ulrich_0001.jpg',
#  'Arnold_Scott_0001.jpg',
#  'Hugo_Chavez_0066.jpg',
#  'Jesse_James_Leija_0002.jpg',
#  'Tommy_Maddox_0001.jpg',
#  'Wim_Duisenberg_0001.jpg',
#  'Frank_Taylor_0001.jpg',
#  'Richard_Barry_0001.jpg',
#  'FaridaJalal_81.jpg',
#  'Jimmy_Kimmel_0002.jpg',
#  'Serena_Williams_0003.jpg',
#  'Habib_Rizieq_0003.jpg',
#  'Michael_Kirby_0001.jpg',
#  'Marty_Mornhinweg_0001.jpg',
#  'George_W_Bush_0167.jpg',
#  'Shae-Lynn_Bourne_0001.jpg',
#  'John_Negroponte_0018.jpg',
#  'Andy_Roddick_0012.jpg',
#  'Piers_Sellers_0001.jpg',
#  'William_Joppy_0001.jpg',
#  'Hector_Grullon_0001.jpg',
#  'Elijah_Wood_0001.jpg',
#  'Lewis_Booth_0001.jpg',
#  'Roberto_Canessa_0001.jpg',
#  'Halle_Berry_0012.jpg',
#  'Dwarakish_170.jpg',
#  'Winona_Ryder_0005.jpg',
#  'George_W_Bush_0060.jpg',
#  'Dave_Campo_0002.jpg',
#  'Ricardo_Lagos_0004.jpg',
#  'Frank_Solich_0001.jpg',
#  'George_W_Bush_0347.jpg',
#  'Daniel_Scioli_0001.jpg',
#  'Salma_Hayek_0007.jpg',
#  'John_Ashcroft_0011.jpg',
#  'Mahmoud_Abbas_0019.jpg',
#  'Dwarakish_8.jpg',
#  'Jayamadhuri_57.jpg',
#  'Daniel_Pearl_0001.jpg',
#  'Jean_Charest_0014.jpg',
#  'John_Snow_0011.jpg',
#  'HrithikRoshan_8.jpg',
#  'Jayamadhuri_110.jpg',
#  'Vladimir_Putin_0044.jpg',
#  'George_W_Bush_0453.jpg',
#  'Allyson_Felix_0002.jpg',
#  'Tiger_Woods_0018.jpg',
#  'Juan_Carlos_Ferrero_0006.jpg',
#  'Richard_Pennington_0001.jpg',
#  'Halle_Berry_0009.jpg',
#  'Nizar_Trabelsi_0001.jpg',
#  'Ahmad_Jbarah_0001.jpg',
#  'Hugo_Chavez_0065.jpg',
#  'George_W_Bush_0241.jpg',
#  'George_W_Bush_0312.jpg',
#  'S_Jayakumar_0002.jpg',
#  'Bill_Parcells_0002.jpg',
#  'Shafal_Mosed_0001.jpg',
#  'Mary_Carey_0002.jpg',
#  'Hugo_Chavez_0022.jpg',
#  'Jayamadhuri_126.jpg',
#  'Hillary_Clinton_0011.jpg',
#  'Laila_Ali_0003.jpg',
#  'Pauley_Perrette_0001.jpg',
#  'Dan_Quayle_0001.jpg',
#  'Laura_Bush_0013.jpg',
#  'James_Ivory_0001.jpg',
#  'Abner_Martinez_0001.jpg',
#  'Jonathan_Edwards_0006.jpg',
#  'Paul_Ebert_0001.jpg',
#  'Rick_Lu_0001.jpg',
#  'Bill_Graham_0002.jpg',
#  'Charles_Taylor_0005.jpg',
#  'John_Burnett_0001.jpg',
#  'Arminio_Fraga_0004.jpg',
#  'Gary_Marshall_0001.jpg',
#  'George_HW_Bush_0004.jpg',
#  'HrithikRoshan_120.jpg',
#  'Carmen_Electra_0005.jpg',
#  'Mahmoud_Abbas_0016.jpg',
#  'John_Howard_0018.jpg',
#  'Pupi_Avati_0002.jpg',
#  'Keanu_Reeves_0006.jpg',
#  'Vicente_Fox_0018.jpg',
#  'George_W_Bush_0428.jpg',
#  'Hu_Jintao_0002.jpg',
#  'Gerald_Fitch_0001.jpg',
#  'Gerhard_Schroeder_0039.jpg',
#  'Osmond_Smith_0001.jpg',
#  'Feliciano_Lopez_0001.jpg',
#  'Lance_Armstrong_0008.jpg',
#  'Britney_Spears_0014.jpg',
#  'Gustavo_Terrazas_0001.jpg',
#  'Justine_Pasek_0002.jpg',
#  'Clark_Randt_0001.jpg',
#  'Norm_Coleman_0001.jpg',
#  'Jennifer_Lopez_0018.jpg',
#  'Bulent_Ecevit_0002.jpg',
#  'Sahim_Alwan_0001.jpg',
#  'Winona_Ryder_0006.jpg',
#  'Casey_Crowder_0001.jpg',
#  'FaridaJalal_45.jpg',
#  'Dileep_89.jpg',
#  'Saddam_Hussein_0013.jpg',
#  'Richard_Gephardt_0002.jpg',
#  'HrithikRoshan_184.jpg',
#  'Edward_Arsenault_0001.jpg',
#  'Lucie_Lapovsky_0001.jpg',
#  'Martina_McBride_0002.jpg',
#  'Adam_Kennedy_0001.jpg',
#  'Andre_Agassi_0016.jpg',
#  'Guy_Hemmings_0002.jpg',
#  'Kofi_Annan_0001.jpg',
#  'Tiger_Woods_0017.jpg',
#  'Jimmy_Carter_0004.jpg',
#  'Beth_Blough_0001.jpg',
#  'George_W_Bush_0003.jpg',
#  'Ascencion_Barajas_0001.jpg',
#  'John_Paul_II_0009.jpg',
#  'Michael_Winterbottom_0001.jpg',
#  'James_Smith_0001.jpg',
#  'Romano_Prodi_0001.jpg',
#  'Bob_Ferguson_0001.jpg',
#  'Ray_Romano_0004.jpg',
#  ...]

# %%
pic_labels = pd.read_csv(DATA_DIR)
pic_labels[["image", "emotion"]]
# Out:
#                                  image    emotion
# 0      facial-expressions_2868588k.jpg      anger
# 1      facial-expressions_2868585k.jpg   surprise
# 2      facial-expressions_2868584k.jpg    disgust
# 3      facial-expressions_2868582k.jpg       fear
# 4               Aaron_Eckhart_0001.jpg    neutral
# 5                 Aaron_Guiel_0001.jpg  happiness
# 6             Aaron_Patterson_0001.jpg    neutral
# 7               Aaron_Peirsol_0001.jpg  happiness
# 8               Aaron_Peirsol_0002.jpg  happiness
# 9               Aaron_Peirsol_0003.jpg  happiness
# 10              Aaron_Peirsol_0004.jpg    neutral
# 11                 Aaron_Pena_0001.jpg    neutral
# 12               Aaron_Sorkin_0001.jpg  happiness
# 13               Aaron_Sorkin_0002.jpg  happiness
# 14               Aaron_Tippin_0001.jpg    neutral
# 15           Abbas_Kiarostami_0001.jpg    neutral
# 16                  Abba_Eban_0001.jpg  happiness
# 17        Abdel_Aziz_Al-Hakim_0001.jpg    neutral
# 18         Abdel_Madi_Shabneh_0001.jpg    neutral
# 19        Abdel_Nasser_Assidi_0001.jpg    neutral
# 20        Abdel_Nasser_Assidi_0002.jpg    neutral
# 21             Abdoulaye_Wade_0001.jpg    neutral
# 22             Abdoulaye_Wade_0002.jpg  happiness
# 23             Abdoulaye_Wade_0003.jpg    neutral
# 24             Abdoulaye_Wade_0004.jpg  happiness
# 25          Abdulaziz_Kamilov_0001.jpg    neutral
# 26                   Abdullah_0001.jpg    neutral
# 27                   Abdullah_0002.jpg    neutral
# 28                   Abdullah_0003.jpg    neutral
# 29                   Abdullah_0004.jpg    neutral
# ...                                ...        ...
# 13660            SharmilaTagore_53.jpg  HAPPINESS
# 13661            SharmilaTagore_54.jpg  HAPPINESS
# 13662            SharmilaTagore_55.jpg  HAPPINESS
# 13663            SharmilaTagore_56.jpg  HAPPINESS
# 13664            SharmilaTagore_57.jpg  HAPPINESS
# 13665             SharmilaTagore_6.jpg  HAPPINESS
# 13666            SharmilaTagore_60.jpg  HAPPINESS
# 13667            SharmilaTagore_61.jpg  HAPPINESS
# 13668            SharmilaTagore_62.jpg  HAPPINESS
# 13669            SharmilaTagore_63.jpg  HAPPINESS
# 13670            SharmilaTagore_65.jpg  HAPPINESS
# 13671            SharmilaTagore_66.jpg  HAPPINESS
# 13672            SharmilaTagore_67.jpg  HAPPINESS
# 13673            SharmilaTagore_68.jpg  HAPPINESS
# 13674            SharmilaTagore_69.jpg  HAPPINESS
# 13675            SharmilaTagore_70.jpg  HAPPINESS
# 13676            SharmilaTagore_71.jpg  HAPPINESS
# 13677            SharmilaTagore_72.jpg  HAPPINESS
# 13678            SharmilaTagore_73.jpg  HAPPINESS
# 13679            SharmilaTagore_74.jpg  HAPPINESS
# 13680            SharmilaTagore_75.jpg  HAPPINESS
# 13681            SharmilaTagore_76.jpg  HAPPINESS
# 13682            SharmilaTagore_77.jpg  HAPPINESS
# 13683            SharmilaTagore_79.jpg  HAPPINESS
# 13684             SharmilaTagore_8.jpg  HAPPINESS
# 13685            SharmilaTagore_80.jpg  HAPPINESS
# 13686            SharmilaTagore_81.jpg  HAPPINESS
# 13687            SharmilaTagore_82.jpg  HAPPINESS
# 13688            SharmilaTagore_83.jpg  HAPPINESS
# 13689             SharmilaTagore_9.jpg  HAPPINESS
#
# [13690 rows x 2 columns]

# %%
pic_labels["emotion"].unique()
# Out:
# array(['anger', 'surprise', 'disgust', 'fear', 'neutral', 'happiness',
#        'sadness', 'contempt', 'NEUTRAL', 'SADNESS', 'DISGUST', 'FEAR',
#        'SURPRISE', 'ANGER', 'HAPPINESS'], dtype=object)

# %% [markdown]
# You can see it have some image label with uppercase character. We need to convert it to lowercase.

# %% [markdown]
# ## Make dataset ready for train

# %% [markdown]
# ### Convert uppercase emotion to lowercase

# %%
pic_labels["emotion"] = pic_labels["emotion"].str.lower()

# %%
pic_labels
# Out:
#        user.id                            image    emotion
# 0          628  facial-expressions_2868588k.jpg      anger
# 1          628  facial-expressions_2868585k.jpg   surprise
# 2          628  facial-expressions_2868584k.jpg    disgust
# 3          628  facial-expressions_2868582k.jpg       fear
# 4        dwdii           Aaron_Eckhart_0001.jpg    neutral
# 5          302             Aaron_Guiel_0001.jpg  happiness
# 6          302         Aaron_Patterson_0001.jpg    neutral
# 7          302           Aaron_Peirsol_0001.jpg  happiness
# 8          302           Aaron_Peirsol_0002.jpg  happiness
# 9          302           Aaron_Peirsol_0003.jpg  happiness
# 10         302           Aaron_Peirsol_0004.jpg    neutral
# 11         302              Aaron_Pena_0001.jpg    neutral
# 12         302            Aaron_Sorkin_0001.jpg  happiness
# 13         302            Aaron_Sorkin_0002.jpg  happiness
# 14         302            Aaron_Tippin_0001.jpg    neutral
# 15         302        Abbas_Kiarostami_0001.jpg    neutral
# 16         302               Abba_Eban_0001.jpg  happiness
# 17         302     Abdel_Aziz_Al-Hakim_0001.jpg    neutral
# 18         302      Abdel_Madi_Shabneh_0001.jpg    neutral
# 19         302     Abdel_Nasser_Assidi_0001.jpg    neutral
# 20         302     Abdel_Nasser_Assidi_0002.jpg    neutral
# 21         302          Abdoulaye_Wade_0001.jpg    neutral
# 22         302          Abdoulaye_Wade_0002.jpg  happiness
# 23         302          Abdoulaye_Wade_0003.jpg    neutral
# 24         302          Abdoulaye_Wade_0004.jpg  happiness
# 25         302       Abdulaziz_Kamilov_0001.jpg    neutral
# 26         302                Abdullah_0001.jpg    neutral
# 27         302                Abdullah_0002.jpg    neutral
# 28         302                Abdullah_0003.jpg    neutral
# 29         302                Abdullah_0004.jpg    neutral
# ...        ...                              ...        ...
# 13660  jhamski            SharmilaTagore_53.jpg  happiness
# 13661  jhamski            SharmilaTagore_54.jpg  happiness
# 13662  jhamski            SharmilaTagore_55.jpg  happiness
# 13663  jhamski            SharmilaTagore_56.jpg  happiness
# 13664  jhamski            SharmilaTagore_57.jpg  happiness
# 13665  jhamski             SharmilaTagore_6.jpg  happiness
# 13666  jhamski            SharmilaTagore_60.jpg  happiness
# 13667  jhamski            SharmilaTagore_61.jpg  happiness
# 13668  jhamski            SharmilaTagore_62.jpg  happiness
# 13669  jhamski            SharmilaTagore_63.jpg  happiness
# 13670  jhamski            SharmilaTagore_65.jpg  happiness
# 13671  jhamski            SharmilaTagore_66.jpg  happiness
# 13672  jhamski            SharmilaTagore_67.jpg  happiness
# 13673  jhamski            SharmilaTagore_68.jpg  happiness
# 13674  jhamski            SharmilaTagore_69.jpg  happiness
# 13675  jhamski            SharmilaTagore_70.jpg  happiness
# 13676  jhamski            SharmilaTagore_71.jpg  happiness
# 13677  jhamski            SharmilaTagore_72.jpg  happiness
# 13678  jhamski            SharmilaTagore_73.jpg  happiness
# 13679  jhamski            SharmilaTagore_74.jpg  happiness
# 13680  jhamski            SharmilaTagore_75.jpg  happiness
# 13681  jhamski            SharmilaTagore_76.jpg  happiness
# 13682  jhamski            SharmilaTagore_77.jpg  happiness
# 13683  jhamski            SharmilaTagore_79.jpg  happiness
# 13684  jhamski             SharmilaTagore_8.jpg  happiness
# 13685  jhamski            SharmilaTagore_80.jpg  happiness
# 13686  jhamski            SharmilaTagore_81.jpg  happiness
# 13687  jhamski            SharmilaTagore_82.jpg  happiness
# 13688  jhamski            SharmilaTagore_83.jpg  happiness
# 13689  jhamski             SharmilaTagore_9.jpg  happiness
#
# [13690 rows x 3 columns]

# %%
pic_labels[["image", "emotion"]].values
# Out:
# array([['facial-expressions_2868588k.jpg', 'anger'],
#        ['facial-expressions_2868585k.jpg', 'surprise'],
#        ['facial-expressions_2868584k.jpg', 'disgust'],
#        ...,
#        ['SharmilaTagore_82.jpg', 'happiness'],
#        ['SharmilaTagore_83.jpg', 'happiness'],
#        ['SharmilaTagore_9.jpg', 'happiness']], dtype=object)

# %%
pic_labels["int_label"], itest = pic_labels["emotion"].factorize()
pic_labels
# Out:
#        user.id                            image    emotion  int_label
# 0          628  facial-expressions_2868588k.jpg      anger          0
# 1          628  facial-expressions_2868585k.jpg   surprise          1
# 2          628  facial-expressions_2868584k.jpg    disgust          2
# 3          628  facial-expressions_2868582k.jpg       fear          3
# 4        dwdii           Aaron_Eckhart_0001.jpg    neutral          4
# 5          302             Aaron_Guiel_0001.jpg  happiness          5
# 6          302         Aaron_Patterson_0001.jpg    neutral          4
# 7          302           Aaron_Peirsol_0001.jpg  happiness          5
# 8          302           Aaron_Peirsol_0002.jpg  happiness          5
# 9          302           Aaron_Peirsol_0003.jpg  happiness          5
# 10         302           Aaron_Peirsol_0004.jpg    neutral          4
# 11         302              Aaron_Pena_0001.jpg    neutral          4
# 12         302            Aaron_Sorkin_0001.jpg  happiness          5
# 13         302            Aaron_Sorkin_0002.jpg  happiness          5
# 14         302            Aaron_Tippin_0001.jpg    neutral          4
# 15         302        Abbas_Kiarostami_0001.jpg    neutral          4
# 16         302               Abba_Eban_0001.jpg  happiness          5
# 17         302     Abdel_Aziz_Al-Hakim_0001.jpg    neutral          4
# 18         302      Abdel_Madi_Shabneh_0001.jpg    neutral          4
# 19         302     Abdel_Nasser_Assidi_0001.jpg    neutral          4
# 20         302     Abdel_Nasser_Assidi_0002.jpg    neutral          4
# 21         302          Abdoulaye_Wade_0001.jpg    neutral          4
# 22         302          Abdoulaye_Wade_0002.jpg  happiness          5
# 23         302          Abdoulaye_Wade_0003.jpg    neutral          4
# 24         302          Abdoulaye_Wade_0004.jpg  happiness          5
# 25         302       Abdulaziz_Kamilov_0001.jpg    neutral          4
# 26         302                Abdullah_0001.jpg    neutral          4
# 27         302                Abdullah_0002.jpg    neutral          4
# 28         302                Abdullah_0003.jpg    neutral          4
# 29         302                Abdullah_0004.jpg    neutral          4
# ...        ...                              ...        ...        ...
# 13660  jhamski            SharmilaTagore_53.jpg  happiness          5
# 13661  jhamski            SharmilaTagore_54.jpg  happiness          5
# 13662  jhamski            SharmilaTagore_55.jpg  happiness          5
# 13663  jhamski            SharmilaTagore_56.jpg  happiness          5
# 13664  jhamski            SharmilaTagore_57.jpg  happiness          5
# 13665  jhamski             SharmilaTagore_6.jpg  happiness          5
# 13666  jhamski            SharmilaTagore_60.jpg  happiness          5
# 13667  jhamski            SharmilaTagore_61.jpg  happiness          5
# 13668  jhamski            SharmilaTagore_62.jpg  happiness          5
# 13669  jhamski            SharmilaTagore_63.jpg  happiness          5
# 13670  jhamski            SharmilaTagore_65.jpg  happiness          5
# 13671  jhamski            SharmilaTagore_66.jpg  happiness          5
# 13672  jhamski            SharmilaTagore_67.jpg  happiness          5
# 13673  jhamski            SharmilaTagore_68.jpg  happiness          5
# 13674  jhamski            SharmilaTagore_69.jpg  happiness          5
# 13675  jhamski            SharmilaTagore_70.jpg  happiness          5
# 13676  jhamski            SharmilaTagore_71.jpg  happiness          5
# 13677  jhamski            SharmilaTagore_72.jpg  happiness          5
# 13678  jhamski            SharmilaTagore_73.jpg  happiness          5
# 13679  jhamski            SharmilaTagore_74.jpg  happiness          5
# 13680  jhamski            SharmilaTagore_75.jpg  happiness          5
# 13681  jhamski            SharmilaTagore_76.jpg  happiness          5
# 13682  jhamski            SharmilaTagore_77.jpg  happiness          5
# 13683  jhamski            SharmilaTagore_79.jpg  happiness          5
# 13684  jhamski             SharmilaTagore_8.jpg  happiness          5
# 13685  jhamski            SharmilaTagore_80.jpg  happiness          5
# 13686  jhamski            SharmilaTagore_81.jpg  happiness          5
# 13687  jhamski            SharmilaTagore_82.jpg  happiness          5
# 13688  jhamski            SharmilaTagore_83.jpg  happiness          5
# 13689  jhamski             SharmilaTagore_9.jpg  happiness          5
#
# [13690 rows x 4 columns]

# %%
itest
# Out:
# Index(['anger', 'surprise', 'disgust', 'fear', 'neutral', 'happiness',
#        'sadness', 'contempt'],
#       dtype='object')

# %% [markdown]
# ### Create Image Data Generator

# %%
from keras.preprocessing import image
import keras
# Out:
# /home/phongsathron/.local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
emotion_label = list(pic_labels["emotion"].unique())

# %% [markdown]
# #### Split data for train and validate

# %%
train_set = pic_labels[4000:].reset_index()
validation_set = pic_labels[:4000].reset_index()
# test_set = pic_labels[10000:13000].reset_index()

# %%
def load_data(dataset):
    imgs = np.empty((len(dataset),224,224,3),dtype="float32")
    j = 0
    for img_file in dataset["image"]:
        img_path = IMAGE_DIR +"/"+ img_file
        img = image.load_img(img_path, target_size=(224, 224))
        arr = np.asarray(img, dtype="float32")
        imgs[j,:,:,:] = arr
        j += 1
#     labels = np.arange(dataset["emotion"].values.size)
    labels = dataset["int_label"].values
    return imgs, labels

# %%
train_imgs, train_labels = load_data(train_set)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-16-faaf353d23f3> in <module>()
# ----> 1 train_imgs, train_labels = load_data(train_set)
#
# <ipython-input-15-e3e67770e164> in load_data(dataset)
#       1 def load_data(dataset):
# ----> 2     imgs = np.empty((len(dataset),224,224,3),dtype="float32")
#       3     j = 0
#       4     for img_file in dataset["image"]:
#       5         img_path = IMAGE_DIR +"/"+ img_file
#
# MemoryError:

# %%
validate_imgs, validate_labels = load_data(validation_set)

# %%
train_labels = keras.utils.to_categorical(train_labels, 8)
validate_labels = keras.utils.to_categorical(validate_labels, 8)

# %%
# validate_labels

# %%
train_labels.shape

# %%
validate_labels.shape

# %%
# validate_imgs = keras.utils.to_categorical(validate_imgs, 8)
# validate_imgs.shape

# %% [markdown]
# ## Normalize data

# %%
train_imgs /= 255
validate_imgs /= 255

# %% [markdown]
# We need to move image file to sub folders

# %%
# import shutil

# %% [markdown]
# #### Create subfolder and copy images

# %%
# for new_path in emotion_label:
#     if not os.path.exists(IMAGE_DIR+'/../train/'+new_path):
#             os.makedirs(IMAGE_DIR+'/../train/'+new_path)

# for i in range(len(train_set["image"])):
#     shutil.copy(IMAGE_DIR+"/"+train_set["image"][i], IMAGE_DIR+'/../train/'+train_set["emotion"][i]+'/'+train_set["image"][i])

# %%
# for new_path in emotion_label:
#     if not os.path.exists(IMAGE_DIR+'/../validate/'+new_path):
#             os.makedirs(IMAGE_DIR+'/../validate/'+new_path)

# for i in range(len(validation_set["image"])):
#     shutil.copy(IMAGE_DIR+"/"+validation_set["image"][i], IMAGE_DIR+'/../validate/'+validation_set["emotion"][i]+'/'+validation_set["image"][i])

# %% [markdown]
# Gen data

# %%
# train_datagen = image.ImageDataGenerator(
# #     zoom_range = 0.2,
# #     shear_range = 0.2,
# #     horizontal_flip = True
# )

# validation_datagen = image.ImageDataGenerator()

# train_generator = train_datagen.flow_from_directory(
#     IMAGE_DIR+'/../train',
#     target_size=(224,224),
#     batch_size=batch_size,
#     class_mode='categorical',
#     classes = list(pic_labels["emotion"].unique())
# )

# validation_generator = validation_datagen.flow_from_directory(
#     IMAGE_DIR+'/../validate',
#     target_size=(224,224),
#     batch_size=batch_size,
#     class_mode='categorical',
#     classes = list(pic_labels["emotion"].unique())
# )

# %% [markdown]
# Use bottlenect feature

# %% [markdown]
# ## Create Model
# In this notebook. I want to try with VGG model

# %% [markdown]
# ### Import Keras

# %%
from keras.models import Sequential
from keras.layers import Input
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
import keras.applications

# %%
class_num = pic_labels["emotion"].unique().size
class_num

# %%
# model = Sequential()

# #block 1
# model.add(Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=(224, 224, 3)))
# model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2), strides=(2, 2)))

# #block 2
# model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2), strides=(2, 2)))

# #block 3
# model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2), strides=(2, 2)))

# #block 4
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2), strides=(2, 2)))

# #block 5
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2), strides=(2, 2)))

# #Fully Connected
# model.add(Flatten())
# model.add(Dense(4096, activation='relu'))
# model.add(Dense(4096, activation='relu'))
# model.add(Dense(1000, activation='relu'))
# model.add(Dense(class_num, activation='softmax'))

# %%
# model = Sequential()
# model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(224, 224, 3)))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(128, (3, 3), activation='relu'))
# model.add(Conv2D(128, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(256, (3, 3), activation='relu'))
# model.add(Conv2D(256, (3, 3), activation='relu'))
# model.add(Conv2D(256, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(Conv2D(512, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Flatten())
# model.add(Dense(4096, activation='relu'))
# model.add(Dense(4096, activation='relu'))
# model.add(Dense(1000, activation='relu'))
# # model.add(Dropout(0.5))
# model.add(Dense(class_num, activation='softmax'))

# %%
# model = Sequential()
# model.add(Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=(224, 224, 3)))
# model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# model.add(Flatten())
# model.add(Dense(4096, activation='relu'))
# model.add(Dense(4096, activation='relu'))
# model.add(Dense(1000, activation='relu'))
# model.add(Dense(class_num, activation='softmax'))

# %%
model = Sequential()
model.add(keras.applications.resnet50.ResNet50(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3), name='input')))
model.add(Flatten())
model.add(Dense(class_num, activation='softmax'))

# %%
model.summary()

# %%
from keras import optimizers
optimizer = optimizers.Adam()

# %%
model.load_weights('emotion.h5')

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %% [markdown]
# ## Start Training

# %% [markdown]
# Because my GPU problem. I decide to use CPU only.

# %%
# model.fit_generator(
#         train_generator,
#         steps_per_epoch=len(train_set)/batch_size,
#         epochs=30,
#         validation_data=validation_generator,
#         validation_steps=len(validation_generator)/batch_size
# )
# model.save_weights('first_try.h5')

# %%
validate_imgs.shape

# %%
# batch_size = 20
# n_epochs = 20
# model.fit(train_imgs, train_labels, batch_size=batch_size, epochs=n_epochs, validation_data=(validate_imgs, validate_labels))

# %%
model.save_weights('emotion.h5')

# %%
score = model.evaluate(validate_imgs, validate_labels, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
test_img = image.load_img(os.path.abspath("NA.AN2.212.jpg"), target_size=(224, 224))
test_img

# %%
imgs = np.empty((1,224,224,3),dtype="float32")
arr = np.asarray(test_img, dtype="float32")
arr[:] = np.max(test_img,axis=-1,keepdims=1)/2+np.min(test_img,axis=-1,keepdims=1)/2
arr = arr.reshape((224, 224, 3))
imgs[0,:,:,:] = arr
imgs /= 255

# %%
plt.imshow(imgs[0])

# %%
predict = model.predict(imgs)

# %%
emotion_label[predict.argmax(-1)[0]]
